# %%
print("Hello World")

# %%
'''
question 1:
print odd numbers from 1 to 20
'''

for num in range (1, 20+1, 2):
    print(num, end=' ')

# %%
# Q2 - print list items like A-B-C-D 

inputList = ["A", "B", "C", "D"]

print("-".join(tuple(inputList)))
